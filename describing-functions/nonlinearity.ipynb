# %% [markdown]
# # Describing Function Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
import control
from system_sim import System

# %%
SIM_TIME = 30
T_STEP = 0.01

s = control.tf('s')

# %% [markdown]
# ## Define System
#
# ### Laplace Representation

# %%
G = 1/(s*(s+1)*(s+1))
G
# Out:
# TransferFunction(array([1]), array([1, 2, 1, 0]))

# %% [markdown]
# ### State Space

# %%
G_ss = control.tf2ss(G)
G_ss
# Out:
# StateSpace(array([[-2., -1., -0.],
#        [ 1.,  0.,  0.],
#        [ 0.,  1.,  0.]]), array([[1.],
#        [0.],
#        [0.]]), array([[0., 0., 1.]]), array([[0.]]))

# %% [markdown]
# ## Define Nonlinearity - Relay

# %%
# Relay Constant
M = 1

def relay(x):
    return M if x>0 else -M if x<0 else 0

x = list(range(-200,200))
x = [i/100 for i in x]
y = [relay(i) for i in x]

plt.plot(x,y)
plt.axhline(0, color='black', linewidth=.5)
plt.axvline(0, color='black', linewidth=.5)
plt.xlabel("Input")
plt.ylabel("Output")
plt.title("Response of Ideal Relay")
plt.show()

# %% [markdown]
# ## Closed Loop System - No Input

# %%
sys = System(G_ss, T_STEP)
n = int(SIM_TIME/T_STEP)

# Input has small initial disturbance

u = [0]*n
for i in range(5):
    u[i] = 0.1

y = [0]
e = [0]
x = [0]
t = [0]

for i in range(1,n):
    e.append(u[i]-y[i-1])
    x.append(relay(e[i]))
    y.append(sys(x[i]))
    t.append(sys.t_step*i)

plt.plot(t,y)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,10))

plt.subplot(3,1,1)
plt.title("Input")
plt.grid()
plt.plot(t, u)

plt.subplot(3,1,2)
plt.title("Error")
plt.grid()
plt.plot(t, e)

plt.subplot(3,1,3)
plt.title("Relay Output")
plt.grid()
plt.plot(t, x)

plt.show()

# %% [markdown]
# ### Nyquist Plot

# %%
w = np.logspace(-4, 4, 10000)
A = np.logspace(-4, 4, 10000)

GCp = G(1j*w)
GCn = G(-1j*w)

N_inv_neg = -np.pi*A/(4*M)

plt.figure(figsize=(8,5))
plt.plot(np.real(GCp), np.imag(GCp))
plt.plot(np.real(GCn), np.imag(GCn), linestyle='dashed')
plt.plot(np.real(N_inv_neg), np.imag(N_inv_neg), linestyle='dashed')
plt.xlim([-1.5, 1.5])
plt.ylim([-1, 1])
plt.title("Nyquist Plot")
plt.xlabel("Real")
plt.ylabel("Imaginary")
plt.legend(["G(jw)", "G(-jw)"," -1/N(A,w)"])
plt.axhline(0, color='black', linewidth=.5)
plt.axvline(0, color='black', linewidth=.5)
plt.show()

# %% [markdown]
# ## Closed Loop System - Step Input

# %%
sys = System(G_ss, T_STEP)
n = int(SIM_TIME/T_STEP)

# Step input of amplitude 5

u = [5]*n
u[0] = 0

y = [0]
e = [0]
x = [0]
t = [0]

for i in range(1,n):
    e.append(u[i]-y[i-1])
    x.append(relay(e[i]))
    y.append(sys(x[i]))
    t.append(sys.t_step*i)

plt.plot(t,y)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,10))

plt.subplot(3,1,1)
plt.title("Input")
plt.grid()
plt.plot(t, u)

plt.subplot(3,1,2)
plt.title("Error")
plt.grid()
plt.plot(t, e)

plt.subplot(3,1,3)
plt.title("Relay Output")
plt.grid()
plt.plot(t, x)

plt.show()
